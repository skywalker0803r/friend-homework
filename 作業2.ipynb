# %%
import pandas as pd
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # define col

# %%
x_col = df.drop('output',axis=1).columns.tolist()
y_col = 'output'
x_col,y_col
# Out:
# (['age',
#   'sex',
#   'cp',
#   'trtbps',
#   'chol',
#   'fbs',
#   'restecg',
#   'thalachh',
#   'exng',
#   'oldpeak',
#   'slp',
#   'caa',
#   'thall'],
#  'output')

# %% [markdown]
# # LabelEncoder

# %%
from sklearn import preprocessing
le_dict = {}
for col in df.columns:
    le_dict[col] = preprocessing.LabelEncoder()
    le_dict[col].fit(df[col])
    df[col] = le_dict[col].transform(df[col])
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     29    1   3      31    64    1        0        49     0       22    0
# 1      3    1   2      22    80    0        1        84     0       32    0
# 2      7    0   1      22    35    0        0        71     0       14    2
# 3     22    1   1      14    67    0        1        76     0        8    2
# 4     23    0   0      14   145    0        1        62     1        6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   23    0   0      28    71    0        1        23     1        2    1
# 299   11    1   3       8    93    0        1        32     0       12    1
# 300   34    1   0      30    26    1        1        40     0       31    1
# 301   23    1   0      22     1    0        1        16     1       12    1
# 302   23    0   1      22    67    0        0        73     0        0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # 特徵擷取

# %%
X = df[x_col]
y = df[y_col]

# %% [markdown]
# # Tree-based feature selection

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(X, y)
print(clf.feature_importances_ )
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
X.shape,X_new.shape
# Out:
# [0.07902916 0.05916331 0.11312197 0.0618024  0.05551995 0.02070818
#  0.03445092 0.09339607 0.1010026  0.08706948 0.08067673 0.12025924
#  0.09379999]
# c:\Users\ADSL\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ((303, 13), (303, 8))

# %% [markdown]
# # Univariate feature selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
X_new = SelectKBest(chi2, k=2).fit_transform(X, y)
X.shape,X_new.shape
# Out:
# ((303, 13), (303, 2))

# %% [markdown]
# # 學習演算法

# %%
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
clf = make_pipeline(StandardScaler(), SVC(gamma='auto'))
clf.fit(X, y)
clf.score(X,y)
# Out:
# 0.9174917491749175

# %%
from xgboost import XGBClassifier
clf = XGBClassifier()
clf.fit(X,y)
clf.score(X,y)
# Out:
# 1.0

# %% [markdown]
# # 參數最佳化

# %%
import optuna

def objective(trial):
    x1 = trial.suggest_float("C", 1, 100)
    x2 = trial.suggest_float("gamma", 0.01, 1)
    clf = make_pipeline(StandardScaler(), SVC(C = x1,gamma=x2))
    clf.fit(X, y)
    return clf.score(X,y)
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials = 50)
# Out:
# [I 2022-06-28 09:54:28,719] A new study created in memory with name: no-name-1f8fb9e6-4491-439a-ba7b-fe8c0ea3367a
# [I 2022-06-28 09:54:28,736] Trial 0 finished with value: 1.0 and parameters: {'C': 59.39575756303299, 'gamma': 0.3712816931641527}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:28,752] Trial 1 finished with value: 1.0 and parameters: {'C': 11.936951582884634, 'gamma': 0.15750302960548895}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:28
. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,348] Trial 29 finished with value: 1.0 and parameters: {'C': 54.55120765999149, 'gamma': 0.12517950783177445}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,371] Trial 30 finished with value: 1.0 and parameters: {'C': 67.69068756843168, 'gamma': 0.9738634469760206}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,394] Trial 31 finished with value: 1.0 and parameters: {'C': 70.4919942520811, 'gamma': 0.8054061044458886}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,414] Trial 32 finished with value: 1.0 and parameters: {'C': 82.5274919017553, 'gamma': 0.12804766918074706}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,432] Trial 33 finished with value: 0.9504950495049505 and parameters: {'C': 55.23968768773784, 'gamma': 0.018356864998845535}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,455] Trial 34 finished with value: 1.0 and parameters: {'C': 66.39522889850836, 'gamma': 0.9924320112094217}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,478] Trial 35 finished with value: 1.0 and parameters: {'C': 78.57627337684953, 'gamma': 0.8619429616035947}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,501] Trial 36 finished with value: 1.0 and parameters: {'C': 14.129929816207387, 'gamma': 0.6324416734990421}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,523] Trial 37 finished with value: 1.0 and parameters: {'C': 98.0664457631004, 'gamma': 0.5420866565646087}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,546] Trial 38 finished with value: 1.0 and parameters: {'C': 37.28875183348059, 'gamma': 0.3170157976643989}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,568] Trial 39 finished with value: 1.0 and parameters: {'C': 61.49143681080494, 'gamma': 0.7112176522589103}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,590] Trial 40 finished with value: 1.0 and parameters: {'C': 48.90916081981521, 'gamma': 0.5812552787396391}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,613] Trial 41 finished with value: 1.0 and parameters: {'C': 96.58456011973928, 'gamma': 0.407623897823023}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,636] Trial 42 finished with value: 1.0 and parameters: {'C': 91.29857902378286, 'gamma': 0.6780662204830668}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,659] Trial 43 finished with value: 1.0 and parameters: {'C': 52.04064891055278, 'gamma': 0.7550949132853401}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,680] Trial 44 finished with value: 1.0 and parameters: {'C': 84.81566315259738, 'gamma': 0.35268765126240964}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,703] Trial 45 finished with value: 1.0 and parameters: {'C': 71.53839240429215, 'gamma': 0.9299489664180112}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,724] Trial 46 finished with value: 1.0 and parameters: {'C': 93.52958674977958, 'gamma': 0.4126599703330298}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,748] Trial 47 finished with value: 1.0 and parameters: {'C': 76.08175980681236, 'gamma': 0.3229103128445406}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,772] Trial 48 finished with value: 1.0 and parameters: {'C': 62.84450715501687, 'gamma': 0.3765664443426183}. Best is trial 0 with value: 1.0.
# [I 2022-06-28 09:54:29,792] Trial 49 finished with value: 1.0 and parameters: {'C': 55.424991145643354, 'gamma': 0.14239935602950407}. Best is trial 0 with value: 1.0.

# %%
study.best_params['C']
study.best_params['gamma']
# Out:
# 0.3712816931641527

# %% [markdown]
# # 集成學習

# %%
import numpy as np
from sklearn.ensemble import VotingClassifier
clf1 = SVC(C = study.best_params['C'],gamma =study.best_params['gamma'])
clf2 = XGBClassifier()
eclf1 = VotingClassifier(estimators=[('SVC', clf1), ('XGB', clf2)], voting='hard')
eclf1 = eclf1.fit(X, y)
eclf1.score(X,y)
# Out:
# 1.0
